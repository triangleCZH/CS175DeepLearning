# %%
import numpy as np
import os
import six.moves.urllib as urllib
import sys
import tarfile
import tensorflow as tf
import zipfile

from collections import defaultdict
from io import StringIO
from matplotlib import pyplot as plt
from PIL import Image

# This is needed since the notebook is stored in the object_detection folder.
sys.path.append("..")
from object_detection.utils import ops as utils_ops
# Out:
# The history saving thread hit an unexpected error (OperationalError('database or disk is full',)).History will not be written to the database.
# /home/shared/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-d43a26767fa9> in <module>()
#       4 import sys
#       5 import tarfile
# ----> 6 import tensorflow as tf
#       7 import zipfile
#       8
#
# /home/shared/anaconda3/lib/python3.6/site-packages/tensorflow/__init__.py in <module>()
#      22
#      23 # pylint: disable=wildcard-import
# ---> 24 from tensorflow.python import *  # pylint: disable=redefined-builtin
#      25 # pylint: enable=wildcard-import
#      26
#
# /home/shared/anaconda3/lib/python3.6/site-packages/tensorflow/python/__init__.py in <module>()
#      79 # Bring in subpackages.
#      80 from tensorflow.python import data
# ---> 81 from tensorflow.python import keras
#      82 from tensorflow.python.estimator import estimator_lib as estimator
#      83 from tensorflow.python.feature_column import feature_column_lib as feature_column
#
# /home/shared/anaconda3/lib/python3.6/site-packages/tensorflow/python/keras/__init__.py in <module>()
#      24
#      25 # pylint: disable=wildcard-import
# ---> 26 from tensorflow.python.keras import activations
#      27 from tensorflow.python.keras import applications
#      28 from tensorflow.python.keras import backend
#
# /home/shared/anaconda3/lib/python3.6/site-packages/tensorflow/python/keras/activations/__init__.py in <module>()
#      20
#      21 # Activation functions.
# ---> 22 from tensorflow.python.keras._impl.keras.activations import elu
#      23 from tensorflow.python.keras._impl.keras.activations import hard_sigmoid
#      24 from tensorflow.python.keras._impl.keras.activations import linear
#
# /home/shared/anaconda3/lib/python3.6/site-packages/tensorflow/python/keras/_impl/keras/__init__.py in <module>()
#      19 from __future__ import print_function
#      20
# ---> 21 from tensorflow.python.keras._impl.keras import activations
#      22 from tensorflow.python.keras._impl.keras import applications
#      23 from tensorflow.python.keras._impl.keras import backend
#
# /home/shared/anaconda3/lib/python3.6/site-packages/tensorflow/python/keras/_impl/keras/activations.py in <module>()
#      22
#      23 from tensorflow.python.keras._impl.keras import backend as K
# ---> 24 from tensorflow.python.keras._impl.keras.utils.generic_utils import deserialize_keras_object
#      25 from tensorflow.python.layers.base import Layer
#      26 from tensorflow.python.platform import tf_logging as logging
#
# /home/shared/anaconda3/lib/python3.6/site-packages/tensorflow/python/keras/_impl/keras/utils/__init__.py in <module>()
#      29 from tensorflow.python.keras._impl.keras.utils.generic_utils import Progbar
#      30 from tensorflow.python.keras._impl.keras.utils.generic_utils import serialize_keras_object
# ---> 31 from tensorflow.python.keras._impl.keras.utils.io_utils import HDF5Matrix
#      32 from tensorflow.python.keras._impl.keras.utils.layer_utils import convert_all_kernels_in_model
#      33 from tensorflow.python.keras._impl.keras.utils.layer_utils import print_summary
#
# /home/shared/anaconda3/lib/python3.6/site-packages/tensorflow/python/keras/_impl/keras/utils/io_utils.py in <module>()
#      27
#      28 try:
# ---> 29   import h5py
#      30 except ImportError:
#      31   h5py = None
#
# /home/shared/anaconda3/lib/python3.6/site-packages/h5py/__init__.py in <module>()
#      60 from .version import version as __version__
#      61
# ---> 62 from .tests import run_tests
#      63
#      64 if version.hdf5_version_tuple != version.hdf5_built_version_tuple:
#
# /home/shared/anaconda3/lib/python3.6/site-packages/h5py/tests/__init__.py in <module>()
#      11
#      12 import sys
# ---> 13 from .common import ut
#      14
#      15 from . import old, hl
#
# /home/shared/anaconda3/lib/python3.6/site-packages/h5py/tests/common.py in <module>()
#      35 # To test for this, run the testsuite with LC_ALL=C
#      36 try:
# ---> 37     testfile, fname = tempfile.mkstemp(unichr(0x03b7))
#      38 except UnicodeError:
#      39     UNICODE_FILENAMES = False
#
# /home/shared/anaconda3/lib/python3.6/tempfile.py in mkstemp(suffix, prefix, dir, text)
#     333     """
#     334
# --> 335     prefix, suffix, dir, output_type = _sanitize_params(prefix, suffix, dir)
#     336
#     337     if text:
#
# /home/shared/anaconda3/lib/python3.6/tempfile.py in _sanitize_params(prefix, suffix, dir)
#     128     if dir is None:
#     129         if output_type is str:
# --> 130             dir = gettempdir()
#     131         else:
#     132             dir = gettempdirb()
#
# /home/shared/anaconda3/lib/python3.6/tempfile.py in gettempdir()
#     294         try:
#     295             if tempdir is None:
# --> 296                 tempdir = _get_default_tempdir()
#     297         finally:
#     298             _once_lock.release()
#
# /home/shared/anaconda3/lib/python3.6/tempfile.py in _get_default_tempdir()
#     229     raise FileNotFoundError(_errno.ENOENT,
#     230                             "No usable temporary directory found in %s" %
# --> 231                             dirlist)
#     232
#     233 _name_sequence = None
#
# FileNotFoundError: [Errno 2] No usable temporary directory found in ['/tmp', '/var/tmp', '/usr/tmp', '/home/qiaohe/project_cs175']

# %%
import tensorflow
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-d6579f534729> in <module>()
# ----> 1 import tensorflow
#
# /home/shared/anaconda3/lib/python3.6/site-packages/tensorflow/__init__.py in <module>()
#      22
#      23 # pylint: disable=wildcard-import
# ---> 24 from tensorflow.python import *  # pylint: disable=redefined-builtin
#      25 # pylint: enable=wildcard-import
#      26
#
# /home/shared/anaconda3/lib/python3.6/site-packages/tensorflow/python/__init__.py in <module>()
#      79 # Bring in subpackages.
#      80 from tensorflow.python import data
# ---> 81 from tensorflow.python import keras
#      82 from tensorflow.python.estimator import estimator_lib as estimator
#      83 from tensorflow.python.feature_column import feature_column_lib as feature_column
#
# /home/shared/anaconda3/lib/python3.6/site-packages/tensorflow/python/keras/__init__.py in <module>()
#      24
#      25 # pylint: disable=wildcard-import
# ---> 26 from tensorflow.python.keras import activations
#      27 from tensorflow.python.keras import applications
#      28 from tensorflow.python.keras import backend
#
# /home/shared/anaconda3/lib/python3.6/site-packages/tensorflow/python/keras/activations/__init__.py in <module>()
#      20
#      21 # Activation functions.
# ---> 22 from tensorflow.python.keras._impl.keras.activations import elu
#      23 from tensorflow.python.keras._impl.keras.activations import hard_sigmoid
#      24 from tensorflow.python.keras._impl.keras.activations import linear
#
# /home/shared/anaconda3/lib/python3.6/site-packages/tensorflow/python/keras/_impl/keras/__init__.py in <module>()
#      20
#      21 from tensorflow.python.keras._impl.keras import activations
# ---> 22 from tensorflow.python.keras._impl.keras import applications
#      23 from tensorflow.python.keras._impl.keras import backend
#      24 from tensorflow.python.keras._impl.keras import callbacks
#
# /home/shared/anaconda3/lib/python3.6/site-packages/tensorflow/python/keras/_impl/keras/applications/__init__.py in <module>()
#      19 from __future__ import print_function
#      20
# ---> 21 from tensorflow.python.keras._impl.keras.applications.densenet import DenseNet121
#      22 from tensorflow.python.keras._impl.keras.applications.densenet import DenseNet169
#      23 from tensorflow.python.keras._impl.keras.applications.densenet import DenseNet201
#
# /home/shared/anaconda3/lib/python3.6/site-packages/tensorflow/python/keras/_impl/keras/applications/densenet.py in <module>()
#      32 from tensorflow.python.keras._impl.keras.applications.imagenet_utils import _obtain_input_shape
#      33 from tensorflow.python.keras._impl.keras.applications.imagenet_utils import decode_predictions
# ---> 34 from tensorflow.python.keras._impl.keras.engine.network import get_source_inputs
#      35 from tensorflow.python.keras._impl.keras.layers import Activation
#      36 from tensorflow.python.keras._impl.keras.layers import AveragePooling2D
#
# /home/shared/anaconda3/lib/python3.6/site-packages/tensorflow/python/keras/_impl/keras/engine/__init__.py in <module>()
#      19 from __future__ import print_function
#      20
# ---> 21 from tensorflow.python.keras._impl.keras.engine.base_layer import InputSpec
#      22 from tensorflow.python.keras._impl.keras.engine.base_layer import Layer
#      23 from tensorflow.python.keras._impl.keras.engine.input_layer import Input
#
# /home/shared/anaconda3/lib/python3.6/site-packages/tensorflow/python/keras/_impl/keras/engine/base_layer.py in <module>()
#      28 from tensorflow.python.keras._impl.keras import initializers
#      29 from tensorflow.python.keras._impl.keras import regularizers
# ---> 30 from tensorflow.python.keras._impl.keras.utils import generic_utils
#      31 from tensorflow.python.layers import base as tf_base_layers
#      32 from tensorflow.python.platform import tf_logging as logging
#
# /home/shared/anaconda3/lib/python3.6/site-packages/tensorflow/python/keras/_impl/keras/utils/__init__.py in <module>()
#      29 from tensorflow.python.keras._impl.keras.utils.generic_utils import Progbar
#      30 from tensorflow.python.keras._impl.keras.utils.generic_utils import serialize_keras_object
# ---> 31 from tensorflow.python.keras._impl.keras.utils.io_utils import HDF5Matrix
#      32 from tensorflow.python.keras._impl.keras.utils.layer_utils import convert_all_kernels_in_model
#      33 from tensorflow.python.keras._impl.keras.utils.layer_utils import print_summary
#
# /home/shared/anaconda3/lib/python3.6/site-packages/tensorflow/python/keras/_impl/keras/utils/io_utils.py in <module>()
#      27
#      28 try:
# ---> 29   import h5py
#      30 except ImportError:
#      31   h5py = None
#
# /home/shared/anaconda3/lib/python3.6/site-packages/h5py/__init__.py in <module>()
#      60 from .version import version as __version__
#      61
# ---> 62 from .tests import run_tests
#      63
#      64 if version.hdf5_version_tuple != version.hdf5_built_version_tuple:
#
# /home/shared/anaconda3/lib/python3.6/site-packages/h5py/tests/__init__.py in <module>()
#      11
#      12 import sys
# ---> 13 from .common import ut
#      14
#      15 from . import old, hl
#
# /home/shared/anaconda3/lib/python3.6/site-packages/h5py/tests/common.py in <module>()
#      35 # To test for this, run the testsuite with LC_ALL=C
#      36 try:
# ---> 37     testfile, fname = tempfile.mkstemp(unichr(0x03b7))
#      38 except UnicodeError:
#      39     UNICODE_FILENAMES = False
#
# /home/shared/anaconda3/lib/python3.6/tempfile.py in mkstemp(suffix, prefix, dir, text)
#     333     """
#     334
# --> 335     prefix, suffix, dir, output_type = _sanitize_params(prefix, suffix, dir)
#     336
#     337     if text:
#
# /home/shared/anaconda3/lib/python3.6/tempfile.py in _sanitize_params(prefix, suffix, dir)
#     128     if dir is None:
#     129         if output_type is str:
# --> 130             dir = gettempdir()
#     131         else:
#     132             dir = gettempdirb()
#
# /home/shared/anaconda3/lib/python3.6/tempfile.py in gettempdir()
#     294         try:
#     295             if tempdir is None:
# --> 296                 tempdir = _get_default_tempdir()
#     297         finally:
#     298             _once_lock.release()
#
# /home/shared/anaconda3/lib/python3.6/tempfile.py in _get_default_tempdir()
#     229     raise FileNotFoundError(_errno.ENOENT,
#     230                             "No usable temporary directory found in %s" %
# --> 231                             dirlist)
#     232
#     233 _name_sequence = None
#
# FileNotFoundError: [Errno 2] No usable temporary directory found in ['/tmp', '/var/tmp', '/usr/tmp', '/home/qiaohe/project_cs175']
